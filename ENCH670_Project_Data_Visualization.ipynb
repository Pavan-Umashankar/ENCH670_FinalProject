# %%
import pandas as pd
import matplotlib.pyplot as plt

Yeast_Raw = pd.read_csv('ENCH470_YeastDataSet - UpdatedDataSet_CSV.csv')
YeastData = Yeast_Raw.drop('Unnamed: 7', axis='columns')
YeastData
# Out:
#     T (C)   pH  DO (%)  Glucose  Maltodextrin  Sugar Concentration (g/L)  \
# 0     5.0  5.0       0        1             0                       15.0
# 1    10.0  5.0       0        1             0                       15.0
# 2    15.0  5.0       0        1             0                       15.0
# 3    18.5  5.0       0        1             0                       15.0
# 4    22.5  5.0       0        1             0                       15.0
# 5    26.3  5.0       0        1             0                       15.0
# 6    30.0  5.0       0        1             0                       15.0
# 7    31.0  5.0       0        1             0                       15.0
# 8    33.0  5.0       0        1             0                       15.0
# 9    34.0  5.0       0        1             0                       15.0
# 10   35.0  5.0       0        1             0                       15.0
# 11   37.5  5.0       0        1             0                       15.0
# ...

# %%
# Scatter plots of raw data

fig, ax = plt.subplots(2,2, figsize=(12,6))
plt.subplots_adjust(wspace=0.2, hspace=0.4)

ax[0,0].scatter(YeastData['T (C)'],YeastData['mu-max (1/hr)'])
ax[0,0].set_xlabel('Temperature (C)')
ax[0,0].set_ylabel('mu_max (1/hr)')

ax[0,1].scatter(YeastData['pH'],YeastData['mu-max (1/hr)'])
ax[0,1].set_xlabel('pH')
ax[0,1].set_ylabel('mu_max (1/hr)')

ax[1,0].scatter(YeastData['DO (%)'],YeastData['mu-max (1/hr)'])
ax[1,0].set_xlabel('Dissolved Oxygen (%)')
ax[1,0].set_ylabel('mu_max (1/hr)')

ax[1,1].scatter(YeastData['Sugar Concentration (g/L)'],YeastData['mu-max (1/hr)'])
ax[1,1].set_xlabel('Sugar Concentration (g/L)')
ax[1,1].set_ylabel('mu_max (1/hr)')

plt.show()

# %%
# Vary Temperature, others constant

Yeast_temp = YeastData.drop(YeastData.index[13:47])
Yeast_temp

fig, ax = plt.subplots()
ax.scatter(Yeast_temp['T (C)'],Yeast_temp['mu-max (1/hr)'])
ax.set_xlabel('Temperature (C)')
ax.set_ylabel('mu_max (1/hr)')

plt.show()

# %%
# Vary DO %, others constant 

Yeast_DO_4 = YeastData.iloc[13:16,:]
Yeast_DO_5 = YeastData.iloc[16:19,:]
Yeast_DO_6 = YeastData.iloc[19:22,:]

fig, ax = plt.subplots()
ax.scatter(Yeast_DO_4['DO (%)'],Yeast_DO_4['mu-max (1/hr)'])
ax.scatter(Yeast_DO_5['DO (%)'],Yeast_DO_5['mu-max (1/hr)'])
ax.scatter(Yeast_DO_6['DO (%)'],Yeast_DO_6['mu-max (1/hr)'])
ax.set_xlabel('Dissolved Oxygen (%)')
ax.set_ylabel('mu_max (1/hr)')
ax.legend(['pH 4','pH 5','pH 6'])

plt.show()

# %%
# Vary sugar con, others constant

Yeast_SC_28 = YeastData.iloc[22:27,:]
Yeast_SC_30 = YeastData.iloc[[32,36,40,44],:]

fig, ax = plt.subplots(1,2, figsize=(12,6))
plt.subplots_adjust(wspace=0.2, hspace=0.4)

ax[0].scatter(Yeast_SC_28['Sugar Concentration (g/L)'],Yeast_SC_28['mu-max (1/hr)'])
ax[0].set_xlabel('Sugar Concentration (g/L)')
ax[0].set_ylabel('mu_max (1/hr)')
ax[0].legend(['28C'])

ax[1].scatter(Yeast_SC_30['Sugar Concentration (g/L)'],Yeast_SC_30['mu-max (1/hr)'])
ax[1].set_xlabel('Sugar Concentration (g/L)')
ax[1].set_ylabel('mu_max (1/hr)')
ax[1].legend(['30C'])

plt.show()

# %%
# Glucose only
Yeast_glu = YeastData[YeastData['Glucose']==1]

fig, ax = plt.subplots(2,2, figsize=(12,6))
plt.subplots_adjust(wspace=0.2, hspace=0.4)

ax[0,0].scatter(Yeast_glu['T (C)'],Yeast_glu['mu-max (1/hr)'])
ax[0,0].set_xlabel('Temperature (C)')
ax[0,0].set_ylabel('mu_max (1/hr)')

ax[0,1].scatter(Yeast_glu['pH'],Yeast_glu['mu-max (1/hr)'])
ax[0,1].set_xlabel('pH')
ax[0,1].set_ylabel('mu_max (1/hr)')

ax[1,0].scatter(Yeast_glu['DO (%)'],Yeast_glu['mu-max (1/hr)'])
ax[1,0].set_xlabel('Dissolved Oxygen (%)')
ax[1,0].set_ylabel('mu_max (1/hr)')

ax[1,1].scatter(Yeast_glu['Sugar Concentration (g/L)'],Yeast_glu['mu-max (1/hr)'])
ax[1,1].set_xlabel('Sugar Concentration (g/L)')
ax[1,1].set_ylabel('mu_max (1/hr)')

plt.show()

# %%
# Maltodextrin only
# did not include DO% and Temp plots (constant through the malto data)

Yeast_mal = YeastData[YeastData['Maltodextrin']==1]

fig, ax = plt.subplots(1,2, figsize=(12,6))
plt.subplots_adjust(wspace=0.2, hspace=0.4)

ax[0].scatter(Yeast_mal['pH'],Yeast_mal['mu-max (1/hr)'])
ax[0].set_xlabel('pH')
ax[0].set_ylabel('mu_max (1/hr)')

ax[1].scatter(Yeast_mal['Sugar Concentration (g/L)'],Yeast_mal['mu-max (1/hr)'])
ax[1].set_xlabel('Sugar Concentration (g/L)')
ax[1].set_ylabel('mu_max (1/hr)')

plt.show()
